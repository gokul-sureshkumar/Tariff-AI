# %% [markdown]
# # 📊 Price Plan Recommendation — High-Silhouette & Safe Billing (IPYNB)

# %% [markdown]
# This notebook is tuned to:
# - Improve **silhouette** using **MinMaxScaler** and optional **PCA**
# - Prevent **negative bills** via share normalization and safe clipping
# - Deliver **Top‑3 plan recommendations** with ≤25 plans

# %% [markdown]
# ## 0) Setup & Load

# %%
import pandas as pd
import numpy as np
from pathlib import Path

DATA_PATH = Path(r"C:\CTS Hackathon\Price_Plan_Recommendation-main\Price_Plan_Recommendation-main\data\raw\cdr_dataset.csv")
df = pd.read_csv(DATA_PATH).copy()

def normalize(col: str) -> str:
    return col.strip().lower().replace(" ", "_").replace("-", "_").replace(".", "_")
df.rename(columns={c: normalize(c) for c in df.columns}, inplace=True)

print("Loaded shape:", df.shape)
df.head(3)
# Out:
# Loaded shape: (101174, 17)
#   phone_number  account_length  vmail_message  day_mins  day_calls  \
# 0     382-4657             128             25     265.1        110
# 1     371-7191             107             26     161.6        123
# 2     358-1921             137              0     243.4        114
#
#    day_charge  eve_mins  eve_calls  eve_charge  night_mins  night_calls  \
# 0       45.07     197.4         99       16.78       244.7           91
# 1       27.47     195.5        103       16.62       254.4          103
# 2       41.38     121.2        110       10.30       162.6          104
#
#    night_charge  intl_mins  intl_calls  intl_charge  custserv_calls  churn
# 0         11.01       10.0           3         2.70               1  False
# 1         11.45       13.7           3         3.70               1  False
# 2          7.32       12.2           5         3.29               0  False

# %%
import sys
print(sys.executable)
# Out:
# c:\CTS Hackathon\Price_Plan_Recommendation-main\.venv\Scripts\python.exe

# %% [markdown]
# ## 1) Preprocess & Feature Engineering

# %%
aliases = {
    "account_length": ["account_length"],
    "vmail_message": ["vmail_message","voice_mail_messages","voicemail_message"],
    "international_plan": ["international_plan","intl_plan"],
    "voice_mail_plan": ["voice_mail_plan","voicemail_plan"],
    "custserv_calls": ["custserv_calls","customer_service_calls"],
    "day_mins": ["day_mins","total_day_minutes"],
    "eve_mins": ["eve_mins","total_eve_minutes"],
    "night_mins": ["night_mins","total_night_minutes"],
    "intl_mins": ["intl_mins","total_intl_minutes"],
    "day_calls": ["day_calls","total_day_calls"],
    "eve_calls": ["eve_calls","total_eve_calls"],
    "night_calls": ["night_calls","total_night_calls"],
    "intl_calls": ["intl_calls","total_intl_calls"],
    "day_charge": ["day_charge","total_day_charge"],
    "eve_charge": ["eve_charge","total_eve_charge"],
    "night_charge": ["night_charge","total_night_charge"],
    "intl_charge": ["intl_charge","total_intl_charge"],
}

def pick(name):
    for c in aliases.get(name, []):
        if c in df.columns:
            return c
    return None

canonical_map = {k: pick(k) for k in aliases.keys()}

mins_cols   = [canonical_map[c] for c in ["day_mins","eve_mins","night_mins","intl_mins"] if canonical_map.get(c)]
calls_cols  = [canonical_map[c] for c in ["day_calls","eve_calls","night_calls","intl_calls"] if canonical_map.get(c)]
charge_cols = [canonical_map[c] for c in ["day_charge","eve_charge","night_charge","intl_charge"] if canonical_map.get(c)]

if mins_cols:   df["total_mins"]   = df[mins_cols].sum(axis=1)
if calls_cols:  df["total_calls"]  = df[calls_cols].sum(axis=1)
if charge_cols: df["total_charge"] = df[charge_cols].sum(axis=1)

# Shares
if "total_mins" in df.columns:
    for part in ["day","eve","night","intl"]:
        col = canonical_map.get(f"{part}_mins")
        if col:
            df[f"{part}_mins_share"] = df[col] / df["total_mins"].replace(0, np.nan)

# Avg mins per call
if {"total_mins","total_calls"}.issubset(df.columns):
    df["avg_mins_per_call"] = df["total_mins"] / df["total_calls"].replace(0, np.nan)

print("Engineered shape:", df.shape)
df.head(3)
# Out:
# Engineered shape: (101174, 25)
#   phone_number  account_length  vmail_message  day_mins  day_calls  \
# 0     382-4657             128             25     265.1        110
# 1     371-7191             107             26     161.6        123
# 2     358-1921             137              0     243.4        114
#
#    day_charge  eve_mins  eve_calls  eve_charge  night_mins  ...  \
# 0       45.07     197.4         99       16.78       244.7  ...
# 1       27.47     195.5        103       16.62       254.4  ...
# 2       41.38     121.2        110       10.30       162.6  ...
#
#    custserv_calls  churn  total_mins  total_calls  total_charge  \
# 0               1  False       717.2          303         75.56
# 1               1  False       625.2          332         59.24
# 2               0  False       539.4          333         62.29
#
#    day_mins_share  eve_mins_share  night_mins_share  intl_mins_share  \
# 0        0.369632        0.275237          0.341188         0.013943
# 1        0.258477        0.312700          0.406910         0.021913
# 2        0.451242        0.224694          0.301446         0.022618
#
#    avg_mins_per_call
# 0           2.366997
# 1           1.883133
# 2           1.619820
#
# [3 rows x 25 columns]

# %% [markdown]
# ## 2) Data Cleaning (duplicates, missing, outliers)

# %%
before = len(df)

# Keep only unique phone numbers (drop duplicates)
if "phone_number" in df.columns:
    df = df.drop_duplicates(subset=["phone_number"], keep="first")  # keep first occurrence
    print(f"Removed duplicates based on phone_number: {before - len(df)} rows")
else:
    df = df.drop_duplicates()
    print(f"Removed exact duplicate rows: {before - len(df)}")

# Fill missing values with 0
df = df.fillna(0)

# Remove outliers (IQR method) from key usage columns
for col in ["total_mins", "total_calls", "total_charge"]:
    if col in df.columns:
        Q1, Q3 = df[col].quantile(0.25), df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower, upper = Q1 - 1.5 * IQR, Q3 + 1.5 * IQR
        before_out = len(df)
        df = df[(df[col] >= lower) & (df[col] <= upper)]
        print(f"Removed {before_out - len(df)} outliers from {col}")

print("Final dataset shape:", df.shape)
# Out:
# Removed duplicates based on phone_number: 93707 rows
# Removed 0 outliers from total_mins
# Removed 400 outliers from total_calls
# Removed 0 outliers from total_charge
# Final dataset shape: (7067, 25)

# %% [markdown]
# ## 3) Scaling (MinMax) + Optional PCA

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

features = [
    canonical_map.get("account_length"),
    canonical_map.get("vmail_message"),
    "total_mins","total_calls",
    "day_mins_share","eve_mins_share","night_mins_share","intl_mins_share",
    canonical_map.get("custserv_calls"),
]
features = [f for f in features if f is not None]
X = df[features].astype(float).fillna(0)

share_cols = ["day_mins_share","eve_mins_share","night_mins_share","intl_mins_share"]
if all(c in X.columns for c in share_cols):
    S = X[share_cols].sum(axis=1).replace(0, 1.0)
    for c in share_cols:
        X[c] = np.clip(X[c] / S, 0, 1)

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

USE_PCA = True
PCA_COMPONENTS = 6
if USE_PCA:
    pca = PCA(n_components=PCA_COMPONENTS, random_state=42)
    X_for_cluster = pca.fit_transform(X_scaled)
    print("PCA variance:", np.round(pca.explained_variance_ratio_, 3))
else:
    pca = None
    X_for_cluster = X_scaled
# Out:
# PCA variance: [0.418 0.205 0.126 0.068 0.064 0.053]

# %% [markdown]
# ## 4) Silhouette Scan

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

sil_scores = {}
for k in range(4, 11):
    km = KMeans(n_clusters=k, random_state=42, n_init=20)
    labels = km.fit_predict(X_for_cluster)
    sil_scores[k] = round(silhouette_score(X_for_cluster, labels), 3)

print("Silhouette scores:", sil_scores)

plt.plot(list(sil_scores.keys()), list(sil_scores.values()), marker='o')
plt.title("Silhouette vs k )")
plt.xlabel("k")
plt.ylabel("Silhouette")
plt.show()
# Out:
# Silhouette scores: {4: 0.429, 5: 0.385, 6: 0.402, 7: 0.286, 8: 0.269, 9: 0.257, 10: 0.266}

# %% [markdown]
# ## 5) Final Kmeans

# %%
AUTO_PICK_BEST = False
best_k = max(sil_scores, key=sil_scores.get) if AUTO_PICK_BEST else 6
print("Using k =", best_k)

kmeans = KMeans(n_clusters=best_k, random_state=42, n_init=20)
df["Cluster"] = kmeans.fit_predict(X_for_cluster)

final_sil = silhouette_score(X_for_cluster, df["Cluster"])
print(f"Silhouette (final, k={best_k}): {final_sil:.3f}")
# Out:
# Using k = 6
# Silhouette (final, k=6): 0.402

# %% [markdown]
# ## 6) Profiling

# %%
## Cluster profiling for k=6
profile_cols = [
    "total_mins","total_calls","total_charge",
    "day_mins_share","eve_mins_share","night_mins_share","intl_mins_share",
    "avg_mins_per_call"
]
cluster_profile = df.groupby("Cluster")[profile_cols].mean().round(3)
sizes = df["Cluster"].value_counts().sort_index().rename("size")
cluster_profile = pd.concat([sizes, cluster_profile], axis=1)

print("Cluster profiles (k=6):")
cluster_profile
# Out:
# Cluster profiles (k=6):
#          size  total_mins  total_calls  total_charge  day_mins_share  \
# Cluster
# 0        3355     629.340      337.392        61.007           0.305
# 1         854    1370.473      736.317       118.302           0.315
# 2         922    1355.684      723.034       116.097           0.313
# 3         340    1370.241      737.668       118.489           0.317
# 4         356    1370.143      708.365       120.137           0.313
# 5        1240     626.437      336.732        61.011           0.304
#
#          eve_mins_share  night_mins_share  intl_mins_share  avg_mins_per_call
# Cluster
# 0                 0.338             0.338            0.019              1.993
# 1                 0.334             0.331            0.020              2.186
# 2                 0.330             0.336            0.021              2.250
# 3                 0.334             0.329            0.020              2.169
# 4                 0.331             0.335            0.021              2.332
# 5                 0.339             0.338            0.018              1.991

# %% [markdown]
# ## 7) Plan Catalog

# %%
def mk_plan(name, monthly_rental, local_rate, night_rate, eve_rate, intl_rate,
            free_day=0, free_night=0, free_eve=0, free_intl=0):
    return {
        "plan_name": name,
        "monthly_rental": monthly_rental,
        "rate_local_day": local_rate,
        "rate_local_eve": eve_rate,
        "rate_local_night": night_rate,
        "rate_intl": intl_rate,
        "free_day": free_day,
        "free_eve": free_eve,
        "free_night": free_night,
        "free_intl": free_intl,
    }

catalog_specs = [
    # Light Talkers (Cluster ~low mins)
    ("Lite Voice 99",      99, 0.20, 0.12, 0.12, 0.35, 100, 50, 50, 0),
    ("Lite Value 149",    149, 0.18, 0.10, 0.10, 0.32, 200,100,100,0),

    # Day Users
    ("Day Saver 249",     249, 0.15, 0.10, 0.09, 0.28, 500,100,100,0),
    ("Day Pro 349",       349, 0.14, 0.10, 0.09, 0.27, 800,150,150,0),

    # Night Owls
    ("Night Owl 199",     199, 0.18, 0.05, 0.12, 0.32,  50,800,100,0),
    ("Midnight Max 299",  299, 0.17, 0.00, 0.12, 0.30, 100,1500,200,0),

    # Balanced Users
    ("All-Rounder 299",   299, 0.16, 0.08, 0.08, 0.28, 300,300,300,10),
    ("All-Rounder Pro 399",399,0.15, 0.08, 0.08, 0.27, 400,400,400,20),

    # Heavy Talkers
    ("Unlimited Talk 399",399, 0.14, 0.07, 0.07, 0.28, 900,600,600,0),
    ("Ultra Unlimited 499",499,0.13, 0.06, 0.07, 0.26,1200,800,800,0),

    # Global Users
    ("Global Saver 399",  399, 0.16, 0.08, 0.08, 0.23, 300,200,200,50),
    ("Global Connect 599",599, 0.15, 0.08, 0.08, 0.20, 500,300,300,100),
]

catalog = [mk_plan(*spec) for spec in catalog_specs]
catalog_df = pd.DataFrame(catalog)

print("Total plans:", len(catalog_df))
catalog_df
# Out:
# Total plans: 12
#               plan_name  monthly_rental  rate_local_day  rate_local_eve  \
# 0         Lite Voice 99              99            0.20            0.12
# 1        Lite Value 149             149            0.18            0.10
# 2         Day Saver 249             249            0.15            0.09
# 3           Day Pro 349             349            0.14            0.09
# 4         Night Owl 199             199            0.18            0.12
# 5      Midnight Max 299             299            0.17            0.12
# 6       All-Rounder 299             299            0.16            0.08
# 7   All-Rounder Pro 399             399            0.15            0.08
# 8    Unlimited Talk 399             399            0.14            0.07
# 9   Ultra Unlimited 499             499            0.13            0.07
# 10     Global Saver 399             399            0.16            0.08
# 11   Global Connect 599             599            0.15            0.08
#
#     rate_local_night  rate_intl  free_day  free_eve  free_night  free_intl
# 0               0.12       0.35       100        50          50          0
# 1               0.10       0.32       200       100         100          0
# 2               0.10       0.28       500       100         100          0
# 3               0.10       0.27       800       150         150          0
# 4               0.05       0.32        50       100         800          0
# 5               0.00       0.30       100       200        1500          0
# 6               0.08       0.28       300       300         300         10
# 7               0.08       0.27       400       400         400         20
# 8               0.07       0.28       900       600         600          0
# 9               0.06       0.26      1200       800         800          0
# 10              0.08       0.23       300       200         200         50
# 11              0.08       0.20       500       300         300        100

# %% [markdown]
# ## 8) Billing and Recommendation

# %%
# =============================# Enhanced Billing + Recommendations (Fixed)# =============================import numpy as npimport pandas as pdimport matplotlib.pyplot as pltdef safe_normalize_shares(row):    """Safely normalize usage shares"""    keys = ["day_mins_share", "eve_mins_share", "night_mins_share", "intl_mins_share"]    vals = [max(0, float(row.get(k, 0))) for k in keys]    s = sum(vals)    return dict(zip(keys, [0.25, 0.25, 0.25, 0.25] if s <= 0 else [v/s for v in vals]))def estimate_bill(row, plan):    """Calculate estimated bill with safeguards"""    try:        total = max(row.get("total_mins", 0), 0)        shares = safe_normalize_shares(row)                # Calculate minutes for each period        d = shares["day_mins_share"] * total        e = shares["eve_mins_share"] * total        n = shares["night_mins_share"] * total        intl = shares["intl_mins_share"] * total                # Calculate billable minutes (after free minutes)        d_bill = max(d - float(plan["free_day"]), 0)        e_bill = max(e - float(plan["free_eve"]), 0)        n_bill = max(n - float(plan["free_night"]), 0)        i_bill = max(intl - float(plan["free_intl"]), 0)                # Calculate variable charges        variable = (            d_bill * float(plan["rate_local_day"]) +            e_bill * float(plan["rate_local_eve"]) +            n_bill * float(plan["rate_local_night"]) +            i_bill * float(plan["rate_intl"])        )                return round(float(plan["monthly_rental"]) + variable, 2)    except Exception as e:        print(f"Warning: Billing calculation error - {str(e)}")        return float(plan["monthly_rental"])def calculate_plan_suitability(row, plan):    """Calculate plan suitability score (0-1)"""    try:        # Get usage patterns        total = max(row.get("total_mins", 0), 0)        shares = safe_normalize_shares(row)                # Time distribution match (40%)        time_match = 1 - sum([            abs(shares["day_mins_share"] - (plan["free_day"] / (plan["free_day"] + plan["free_eve"] + plan["free_night"]))),            abs(shares["eve_mins_share"] - (plan["free_eve"] / (plan["free_day"] + plan["free_eve"] + plan["free_night"]))),            abs(shares["night_mins_share"] - (plan["free_night"] / (plan["free_day"] + plan["free_eve"] + plan["free_night"])))        ]) / 2                # Usage volume match (30%)        total_free = plan["free_day"] + plan["free_eve"] + plan["free_night"]        volume_match = min(1.0, total_free / max(total, 1))                # Special features match (30%)        special_score = 0.0        if shares["intl_mins_share"] > 0.05 and plan["free_intl"] > 0:            special_score += 0.5        if total > 800 and total_free > 800:            special_score += 0.5                    # Final weighted score        final_score = (            0.4 * time_match +            0.3 * volume_match +            0.3 * special_score        )                return round(float(np.clip(final_score, 0, 1)), 3)    except Exception as e:        print(f"Warning: Suitability calculation error - {str(e)}")        return 0.0def recommend_plans(row, catalog_df, n_recommendations=3):    """Generate diverse plan recommendations"""    try:        recommendations = []                # Calculate scores for all plans        for _, plan in catalog_df.iterrows():            monthly_cost = estimate_bill(row, plan)            suitability = calculate_plan_suitability(row, plan)                        # Get plan category and price tier            category = plan["plan_name"].split()[0]            price_tier = (                'Budget' if plan["monthly_rental"] < 250                 else 'Premium' if plan["monthly_rental"] > 400                 else 'Standard'            )                        recommendations.append({                "plan_name": plan["plan_name"],                "category": category,                "price_tier": price_tier,                "monthly_cost": monthly_cost,                "suitability": suitability,                "final_score": round(0.5 * (1 - monthly_cost/1000) + 0.5 * suitability, 3)            })                # Convert to DataFrame for easier handling        recs_df = pd.DataFrame(recommendations)                # Select diverse recommendations        final_recs = []        categories_used = set()                # First get the absolute best match        best = recs_df.nlargest(1, "final_score").iloc[0]        final_recs.append(best)        categories_used.add(best["category"])                # Then get plans from different categories        remaining = recs_df[~recs_df["category"].isin(categories_used)]        while len(final_recs) < n_recommendations and not remaining.empty:            next_best = remaining.nlargest(1, "final_score").iloc[0]            final_recs.append(next_best)            categories_used.add(next_best["category"])            remaining = recs_df[~recs_df["category"].isin(categories_used)]                # If we still need more, take best remaining        remaining = recs_df[~recs_df["plan_name"].isin([r["plan_name"] for r in final_recs])]        while len(final_recs) < n_recommendations and not remaining.empty:            next_best = remaining.nlargest(1, "final_score").iloc[0]            final_recs.append(next_best)            remaining = remaining[remaining["plan_name"] != next_best["plan_name"]]                return final_recs            except Exception as e:        print(f"Warning: Recommendation error - {str(e)}")        return []# FIX: define phone_col to use the correct dataset columnphone_col = "phone_number"# Generate recommendations for all customersrecs = []for idx, row in df.iterrows():    try:        recommendations = recommend_plans(row, catalog_df)        phone = str(row[phone_col]).strip() if phone_col else None                for rank, rec in enumerate(recommendations, 1):            recs.append({                "index": idx,                "phone": phone,   # FIXED: was phone_number                "cluster": int(row["Cluster"]),                "plan_name": rec["plan_name"],                "category": rec["category"],                "estimated_cost": round(rec["monthly_cost"], 2),                "suitability": rec["suitability"],                "final_score": rec["final_score"],                "rank": rank            })    except Exception as e:        print(f"Warning: Error processing customer {idx} - {str(e)}")        continue# Create recommendations DataFramerecs_df = pd.DataFrame(recs)# Analyze plan distributionprint("\nPlan Distribution Analysis:")print("-" * 50)plan_dist = recs_df["plan_name"].value_counts()print("\nRecommendations per plan:")print(plan_dist)# Visualize distributionplt.figure(figsize=(12, 6))plan_dist.plot(kind='bar')plt.title('Distribution of Recommended Plans')plt.xticks(rotation=45, ha='right')plt.tight_layout()plt.show()# Display sample recommendationsprint("\nSample Recommendations:")display(recs_df.head(10))
# Out:
# Warning: Error processing customer 0 - 'phone'
# Warning: Error processing customer 1 - 'phone'
# Warning: Error processing customer 2 - 'phone'
# Warning: Error processing customer 3 - 'phone'
# Warning: Error processing customer 4 - 'phone'
# Warning: Error processing customer 5 - 'phone'
# Warning: Error processing customer 6 - 'phone'
# Warning: Error processing customer 7 - 'phone'
# Warning: Error processing customer 8 - 'phone'
# Warning: Error processing customer 9 - 'phone'
# Warning: Error processing customer 10 - 'phone'
# Warning: Error processing customer 11 - 'phone'
# Warning: Error processing customer 12 - 'phone'
# Warning: Error processing customer 13 - 'phone'
# Warning: Error processing customer 14 - 'phone'
# Warning: Error processing customer 15 - 'phone'
# Warning: Error processing customer 16 - 'phone'
# Warning: Error processing customer 17 - 'phone'
# Warning: Error processing customer 18 - 'phone'
# Warning: Error processing customer 19 - 'phone'
# Warning: Error processing customer 20 - 'phone'
# Warning: Error processing customer 21 - 'phone'
# Warning: Error processing customer 22 - 'phone'
# Warning: Error processing customer 23 - 'phone'
# Warning: Error processing customer 24 - 'phone'
# Warning: Error processing customer 25 - 'phone'
# Warning: Error processing customer 26 - 'phone'
# Warning: Error processing customer 27 - 'phone'
# Warning: Error processing customer 28 - 'phone'
# Warning: Error processing customer 29 - 'phone'
# Warning: Error processing customer 30 - 'phone'
# Warning: Error processing customer 31 - 'phone'
# Warning: Error processing customer 32 - 'phone'
# Warning: Error processing customer 33 - 'phone'
# Warning: Error processing customer 34 - 'phone'
# Warning: Error processing customer 35 - 'phone'
# Warning: Error processing customer 36 - 'phone'
# Warning: Error processing customer 37 - 'phone'
# Warning: Error processing customer 38 - 'phone'
# Warning: Error processing customer 39 - 'phone'
# Warning: Error processing customer 40 - 'phone'
# Warning: Error processing customer 41 - 'phone'
# Warning: Error processing customer 42 - 'phone'
# Warning: Error processing customer 43 - 'phone'
# Warning: Error processing customer 44 - 'phone'
# Warning: Error processing customer 45 - 'phone'
# Warning: Error processing customer 46 - 'phone'
# Warning: Error processing customer 47 - 'phone'
# Warning: Error processing customer 48 - 'phone'
# Warning: Error processing customer 49 - 'phone'
# Warning: Error processing customer 50 - 'phone'
# Warning: Error processing customer 51 - 'phone'
# Warning: Error processing customer 52 - 'phone'
# Warning: Error processing customer 53 - 'phone'
# Warning: Error processing customer 54 - 'phone'
# Warning: Error processing customer 55 - 'phone'
# Warning: Error processing customer 56 - 'phone'
# Warning: Error processing customer 57 - 'phone'
# Warning: Error processing customer 58 - 'phone'
# Warning: Error processing customer 59 - 'phone'
# Warning: Error processing customer 60 - 'phone'
# Warning: Error processing customer 61 - 'phone'
# Warning: Error processing customer 62 - 'phone'
# Warning: Error processing customer 63 - 'phone'
# Warning: Error processing customer 64 - 'phone'
# Warning: Error processing customer 65 - 'phone'
# Warning: Error processing customer 66 - 'phone'
# Warning: Error processing customer 67 - 'phone'
# Warning: Error processing customer 68 - 'phone'
# Warning: Error processing customer 69 - 'phone'
# Warning: Error processing customer 70 - 'phone'
# Warning: Error processing customer 71 - 'phone'
# Warning: Error processing customer 72 - 'phone'
# Warning: Error processing customer 73 - 'phone'
# Warning: Error processing customer 74 - 'phone'
# Warning: Error processing customer 75 - 'phone'
# Warning: Error processing customer 76 - 'phone'
# Warning: Error processing customer 77 - 'phone'
# Warning: Error processing customer 78 - 'phone'
# Warning: Error processing customer 79 - 'phone'
# Warning: Error processing customer 80 - 'phone'
# Warning: Error processing customer 81 - 'phone'
# Warning: Error processing customer 82 - 'phone'
# Warning: Error processing customer 83 - 'phone'
# Warning: Error processing customer 84 - 'phone'
# Warning: Error processing customer 85 - 'phone'
# Warning: Error processing customer 86 - 'phone'
# Warning: Error processing customer 87 - 'phone'
# Warning: Error processing customer 88 - 'phone'
# Warning: Error processing customer 89 - 'phone'
# Warning: Error processing customer 90 - 'phone'
# Warning: Error processing customer 91 - 'phone'
# Warning: Error processing customer 92 - 'phone'
# Warning: Error processing customer 93 - 'phone'
# Warning: Error processing customer 94 - 'phone'
# Warning: Error processing customer 95 - 'phone'
# Warning: Error processing customer 96 - 'phone'
# Warning: Error processing customer 97 - 'phone'
# Warning: Error processing customer 98 - 'phone'
# Warning: Error processing customer 99 - 'phone'
# Warning: Error processing customer 100 - 'phone'
# Warning: Error processing customer 101 - 'phone'
# Warning: Error processing customer 102 - 'phone'
# Warning: Error processing customer 103 - 'phone'
# Warning: Error processing customer 104 - 'phone'
# Warning: Error processing customer 105 - 'phone'
# Warning: Error processing customer 106 - 'phone'
# Warning: Error processing customer 107 - 'phone'
# Warning: Error processing customer 108 - 'phone'
# Warning: Error processing customer 109 - 'phone'
# Warning: Error processing customer 110 - 'phone'
# Warning: Error processing customer 111 - 'phone'
# Warning: Error processing customer 112 - 'phone'
# Warning: Error processing customer 113 - 'phone'
# Warning: Error processing customer 114 - 'phone'
# Warning: Error processing customer 115 - 'phone'
# Warning: Error processing customer 116 - 'phone'
# Warning: Error processing customer 117 - 'phone'
# Warning: Error processing customer 118 - 'phone'
# Warning: Error processing customer 119 - 'phone'
# Warning: Error processing customer 120 - 'phone'
# Warning: Error processing customer 121 - 'phone'
# Warning: Error processing customer 122 - 'phone'
# Warning: Error processing customer 123 - 'phone'
# Warning: Error processing customer 124 - 'phone'
# Warning: Error processing customer 125 - 'phone'
# Warning: Error processing customer 126 - 'phone'
# Warning: Error processing customer 127 - 'phone'
# Warning: Error processing customer 128 - 'phone'
# Warning: Error processing customer 129 - 'phone'
# Warning: Error processing customer 130 - 'phone'
# Warning: Error processing customer 131 - 'phone'
# Warning: Error processing customer 132 - 'phone'
# Warning: Error processing customer 133 - 'phone'
# Warning: Error processing customer 134 - 'phone'
# Warning: Error processing customer 135 - 'phone'
# Warning: Error processing customer 136 - 'phone'
# Warning: Error processing customer 137 - 'phone'
# Warning: Error processing customer 138 - 'phone'
# Warning: Error processing customer 139 - 'phone'
# Warning: Error processing customer 140 - 'phone'
# Warning: Error processing customer 141 - 'phone'
# Warning: Error processing customer 142 - 'phone'
# Warning: Error processing customer 143 - 'phone'
# Warning: Error processing customer 144 - 'phone'
# Warning: Error processing customer 145 - 'phone'
# Warning: Error processing customer 146 - 'phone'
# Warning: Error processing customer 147 - 'phone'
# Warning: Error processing customer 148 - 'phone'
# Warning: Error processing customer 149 - 'phone'
# Warning: Error processing customer 150 - 'phone'
# Warning: Error processing customer 151 - 'phone'
# Warning: Error processing customer 152 - 'phone'
# Warning: Error processing customer 153 - 'phone'
# Warning: Error processing customer 154 - 'phone'
# Warning: Error processing customer 155 - 'phone'
# Warning: Error processing customer 156 - 'phone'
# Warning: Error processing customer 157 - 'phone'
# Warning: Error processing customer 158 - 'phone'
# Warning: Error processing customer 159 - 'phone'
# Warning: Error processing customer 160 - 'phone'
# Warning: Error processing customer 161 - 'phone'
# Warning: Error processing customer 162 - 'phone'
# Warning: Error processing customer 163 - 'phone'
# Warning: Error processing customer 164 - 'phone'
# Warning: Error processing customer 165 - 'phone'
# Warning: Error processing customer 166 - 'phone'
# Warning: Error processing customer 167 - 'phone'
# Warning: Error processing customer 168 - 'phone'
# Warning: Error processing customer 169 - 'phone'
# Warning: Error processing customer 170 - 'phone'
# Warning: Error processing customer 171 - 'phone'
# Warning: Error processing customer 172 - 'phone'
# Warning: Error processing customer 173 - 'phone'
# Warning: Error processing customer 174 - 'phone'
# Warning: Error processing customer 175 - 'phone'
# Warning: Error processing customer 176 - 'phone'
# Warning: Error processing customer 177 - 'phone'
# Warning: Error processing customer 178 - 'phone'
# Warning: Error processing customer 179 - 'phone'
# Warning: Error processing customer 180 - 'phone'
# Warning: Error processing customer 181 - 'phone'
# Warning: Error processing customer 182 - 'phone'
# Warning: Error processing customer 183 - 'phone'
# Warning: Error processing customer 184 - 'phone'
# Warning: Error processing customer 185 - 'phone'
# Warning: Error processing customer 186 - 'phone'
# Warning: Error processing customer 187 - 'phone'
# Warning: Error processing customer 188 - 'phone'
# Warning: Error processing customer 189 - 'phone'
# Warning: Error processing customer 190 - 'phone'
# Warning: Error processing customer 191 - 'phone'
# Warning: Error processing customer 192 - 'phone'
# Warning: Error processing customer 193 - 'phone'
# Warning: Error processing customer 194 - 'phone'
# Warning: Error processing customer 195 - 'phone'
# Warning: Error processing customer 196 - 'phone'
# Warning: Error processing customer 197 - 'phone'
# Warning: Error processing customer 198 - 'phone'
# Warning: Error processing customer 199 - 'phone'
# Warning: Error processing customer 200 - 'phone'
# Warning: Error processing customer 201 - 'phone'
# Warning: Error processing customer 202 - 'phone'
# Warning: Error processing customer 203 - 'phone'
# Warning: Error processing customer 204 - 'phone'
# Warning: Error processing customer 205 - 'phone'
# Warning: Error processing customer 206 - 'phone'
# Warning: Error processing customer 207 - 'phone'
# Warning: Error processing customer 208 - 'phone'
# Warning: Error processing customer 209 - 'phone'
# Warning: Error processing customer 210 - 'phone'
# Warning: Error processing customer 211 - 'phone'
# Warning: Error processing customer 212 - 'phone'
# Warning: Error processing customer 213 - 'phone'
# Warning: Error processing customer 214 - 'phone'
# Warning: Error processing customer 215 - 'phone'
# Warning: Error processing customer 216 - 'phone'
# Warning: Error processing customer 217 - 'phone'
# Warning: Error processing customer 218 - 'phone'
# Warning: Error processing customer 219 - 'phone'
# Warning: Error processing customer 220 - 'phone'
# Warning: Error processing customer 221 - 'phone'
# Warning: Error processing customer 222 - 'phone'
# Warning: Error processing customer 223 - 'phone'
# Warning: Error processing customer 224 - 'phone'
# Warning: Error processing customer 225 - 'phone'
# Warning: Error processing customer 226 - 'phone'
# Warning: Error processing customer 227 - 'phone'
# Warning: Error processing customer 228 - 'phone'
# Warning: Error processing customer 229 - 'phone'
# Warning: Error processing customer 230 - 'phone'
# Warning: Error processing customer 231 - 'phone'
# Warning: Error processing customer 232 - 'phone'
# Warning: Error processing customer 233 - 'phone'
# Warning: Error processing customer 234 - 'phone'
# Warning: Error processing customer 235 - 'phone'
# Warning: Error processing customer 236 - 'phone'
# Warning: Error processing customer 237 - 'phone'
# Warning: Error processing customer 238 - 'phone'
# Warning: Error processing customer 239 - 'phone'
# Warning: Error processing customer 240 - 'phone'
# Warning: Error processing customer 241 - 'phone'
# Warning: Error processing customer 242 - 'phone'
# Warning: Error processing customer 243 - 'phone'
# Warning: Error processing customer 244 - 'phone'
# Warning: Error processing customer 245 - 'phone'
# Warning: Error processing customer 246 - 'phone'
# Warning: Error processing customer 247 - 'phone'
# Warning: Error processing customer 248 - 'phone'
# Warning: Error processing customer 249 - 'phone'
# Warning: Error processing customer 250 - 'phone'
# Warning: Error processing customer 251 - 'phone'
# Warning: Error processing customer 252 - 'phone'
# Warning: Error processing customer 253 - 'phone'
# Warning: Error processing customer 254 - 'phone'
# Warning: Error processing customer 255 - 'phone'
# Warning: Error processing customer 256 - 'phone'
# Warning: Error processing customer 257 - 'phone'
# Warning: Error processing customer 258 - 'phone'
# Warning: Error processing customer 259 - 'phone'
# Warning: Error processing customer 260 - 'phone'
# Warning: Error processing customer 261 - 'phone'
# Warning: Error processing customer 262 - 'phone'
# Warning: Error processing customer 263 - 'phone'
# Warning: Error processing customer 264 - 'phone'
# Warning: Error processing customer 265 - 'phone'
# Warning: Error processing customer 266 - 'phone'
# Warning: Error processing customer 267 - 'phone'
# Warning: Error processing customer 268 - 'phone'
# Warning: Error processing customer 269 - 'phone'
# Warning: Error processing customer 270 - 'phone'
# Warning: Error processing customer 271 - 'phone'
# Warning: Error processing customer 272 - 'phone'
# Warning: Error processing customer 273 - 'phone'
# Warning: Error processing customer 274 - 'phone'
# Warning: Error processing customer 275 - 'phone'
# Warning: Error processing customer 276 - 'phone'
# Warning: Error processing customer 277 - 'phone'
# Warning: Error processing customer 278 - 'phone'
# Warning: Error processing customer 279 - 'phone'
# Warning: Error processing customer 280 - 'phone'
# Warning: Error processing customer 281 - 'phone'
# Warning: Error processing customer 282 - 'phone'
# Warning: Error processing customer 283 - 'phone'
# Warning: Error processing customer 284 - 'phone'
# Warning: Error processing customer 285 - 'phone'
# Warning: Error processing customer 286 - 'phone'
# Warning: Error processing customer 287 - 'phone'
# Warning: Error processing customer 288 - 'phone'
# Warning: Error processing customer 289 - 'phone'
# Warning: Error processing customer 290 - 'phone'
# Warning: Error processing customer 291 - 'phone'
# Warning: Error processing customer 292 - 'phone'
# Warning: Error processing customer 293 - 'phone'
# Warning: Error processing customer 294 - 'phone'
# Warning: Error processing customer 295 - 'phone'
# Warning: Error processing customer 296 - 'phone'
# Warning: Error processing customer 297 - 'phone'
# Warning: Error processing customer 298 - 'phone'
# Warning: Error processing customer 299 - 'phone'
# Warning: Error processing customer 300 - 'phone'
# Warning: Error processing customer 301 - 'phone'
# Warning: Error processing customer 302 - 'phone'
# Warning: Error processing customer 303 - 'phone'
# Warning: Error processing customer 304 - 'phone'
# Warning: Error processing customer 305 - 'phone'
# Warning: Error processing customer 306 - 'phone'
# Warning: Error processing customer 307 - 'phone'
# Warning: Error processing customer 308 - 'phone'
# Warning: Error processing customer 309 - 'phone'
# Warning: Error processing customer 310 - 'phone'
# Warning: Error processing customer 311 - 'phone'
# Warning: Error processing customer 312 - 'phone'
# Warning: Error processing customer 313 - 'phone'
# Warning: Error processing customer 314 - 'phone'
# Warning: Error processing customer 315 - 'phone'
# Warning: Error processing customer 316 - 'phone'
# Warning: Error processing customer 317 - 'phone'
# Warning: Error processing customer 318 - 'phone'
# Warning: Error processing customer 319 - 'phone'
# Warning: Error processing customer 320 - 'phone'
# Warning: Error processing customer 321 - 'phone'
# Warning: Error processing customer 322 - 'phone'
# Warning: Error processing customer 323 - 'phone'
# Warning: Error processing customer 324 - 'phone'
# Warning: Error processing customer 325 - 'phone'
# Warning: Error processing customer 326 - 'phone'
# Warning: Error processing customer 327 - 'phone'
# Warning: Error processing customer 328 - 'phone'
# Warning: Error processing customer 329 - 'phone'
# Warning: Error processing customer 330 - 'phone'
# Warning: Error processing customer 331 - 'phone'
# Warning: Error processing customer 332 - 'phone'
# Warning: Error processing customer 333 - 'phone'
# Warning: Error processing customer 334 - 'phone'
# Warning: Error processing customer 335 - 'phone'
# Warning: Error processing customer 336 - 'phone'
# Warning: Error processing customer 337 - 'phone'
# Warning: Error processing customer 338 - 'phone'
# Warning: Error processing customer 339 - 'phone'
# Warning: Error processing customer 340 - 'phone'
# Warning: Error processing customer 341 - 'phone'
# Warning: Error processing customer 342 - 'phone'
# Warning: Error processing customer 343 - 'phone'
# Warning: Error processing customer 344 - 'phone'
# Warning: Error processing customer 345 - 'phone'
# Warning: Error processing customer 346 - 'phone'
# Warning: Error processing customer 347 - 'phone'
# Warning: Error processing customer 348 - 'phone'
# Warning: Error processing customer 349 - 'phone'
# Warning: Error processing customer 350 - 'phone'
# Warning: Error processing customer 351 - 'phone'
# Warning: Error processing customer 352 - 'phone'
# Warning: Error processing customer 353 - 'phone'
# Warning: Error processing customer 354 - 'phone'
# Warning: Error processing customer 355 - 'phone'
# Warning: Error processing customer 356 - 'phone'
# Warning: Error processing customer 357 - 'phone'
# Warning: Error processing customer 358 - 'phone'
# Warning: Error processing customer 359 - 'phone'
# Warning: Error processing customer 360 - 'phone'
# Warning: Error processing customer 361 - 'phone'
# Warning: Error processing customer 362 - 'phone'
# Warning: Error processing customer 363 - 'phone'
# Warning: Error processing customer 364 - 'phone'
# Warning: Error processing customer 365 - 'phone'
# Warning: Error processing customer 366 - 'phone'
# Warning: Error processing customer 367 - 'phone'
# Warning: Error processing customer 368 - 'phone'
# Warning: Error processing customer 369 - 'phone'
# Warning: Error processing customer 370 - 'phone'
# Warning: Error processing customer 371 - 'phone'
# Warning: Error processing customer 372 - 'phone'
# Warning: Error processing customer 373 - 'phone'
# Warning: Error processing customer 374 - 'phone'
# Warning: Error processing customer 375 - 'phone'
# Warning: Error processing customer 376 - 'phone'
# Warning: Error processing customer 377 - 'phone'
# Warning: Error processing customer 378 - 'phone'
# Warning: Error processing customer 379 - 'phone'
# Warning: Error processing customer 380 - 'phone'
# Warning: Error processing customer 381 - 'phone'
# Warning: Error processing customer 382 - 'phone'
# Warning: Error processing customer 383 - 'phone'
# Warning: Error processing customer 384 - 'phone'
# Warning: Error processing customer 385 - 'phone'
# Warning: Error processing customer 386 - 'phone'
# Warning: Error processing customer 387 - 'phone'
# Warning: Error processing customer 388 - 'phone'
# Warning: Error processing customer 389 - 'phone'
# Warning: Error processing customer 390 - 'phone'
# Warning: Error processing customer 391 - 'phone'
# Warning: Error processing customer 392 - 'phone'
# Warning: Error processing customer 393 - 'phone'
# Warning: Error processing customer 394 - 'phone'
# Warning: Error processing customer 395 - 'phone'
# Warning: Error processing customer 396 - 'phone'
# Warning: Error processing customer 397 - 'phone'
# Warning: Error processing customer 398 - 'phone'
# Warning: Error processing customer 399 - 'phone'
# Warning: Error processing customer 400 - 'phone'
# Warning: Error processing customer 401 - 'phone'
# Warning: Error processing customer 402 - 'phone'
# Warning: Error processing customer 403 - 'phone'
# Warning: Error processing customer 404 - 'phone'
# Warning: Error processing customer 405 - 'phone'
# Warning: Error processing customer 406 - 'phone'
# Warning: Error processing customer 407 - 'phone'
# Warning: Error processing customer 408 - 'phone'
# Warning: Error processing customer 409 - 'phone'
# Warning: Error processing customer 410 - 'phone'
# Warning: Error processing customer 411 - 'phone'
# Warning: Error processing customer 412 - 'phone'
# Warning: Error processing customer 413 - 'phone'
# Warning: Error processing customer 414 - 'phone'
# Warning: Error processing customer 415 - 'phone'
# Warning: Error processing customer 416 - 'phone'
# Warning: Error processing customer 417 - 'phone'
# Warning: Error processing customer 418 - 'phone'
# Warning: Error processing customer 419 - 'phone'
# Warning: Error processing customer 420 - 'phone'
# Warning: Error processing customer 421 - 'phone'
# Warning: Error processing customer 422 - 'phone'
# Warning: Error processing customer 423 - 'phone'
# Warning: Error processing customer 424 - 'phone'
# Warning: Error processing customer 425 - 'phone'
# Warning: Error processing customer 426 - 'phone'
# Warning: Error processing customer 427 - 'phone'
# Warning: Error processing customer 428 - 'phone'
# Warning: Error processing customer 429 - 'phone'
# Warning: Error processing customer 430 - 'phone'
# Warning: Error processing customer 431 - 'phone'
# Warning: Error processing customer 432 - 'phone'
# Warning: Error processing customer 433 - 'phone'
# Warning: Error processing customer 434 - 'phone'
# Warning: Error processing customer 435 - 'phone'
# Warning: Error processing customer 436 - 'phone'
# Warning: Error processing customer 437 - 'phone'
# Warning: Error processing customer 438 - 'phone'
# Warning: Error processing customer 439 - 'phone'
# Warning: Error processing customer 440 - 'phone'
# Warning: Error processing customer 441 - 'phone'
# Warning: Error processing customer 442 - 'phone'
# Warning: Error processing customer 443 - 'phone'
# Warning: Error processing customer 444 - 'phone'
# Warning: Error processing customer 445 - 'phone'
# Warning: Error processing customer 446 - 'phone'
# Warning: Error processing customer 447 - 'phone'
# Warning: Error processing customer 448 - 'phone'
# Warning: Error processing customer 449 - 'phone'
# Warning: Error processing customer 450 - 'phone'
# Warning: Error processing customer 451 - 'phone'
# Warning: Error processing customer 452 - 'phone'
# Warning: Error processing customer 453 - 'phone'
# Warning: Error processing customer 454 - 'phone'
# Warning: Error processing customer 455 - 'phone'
# Warning: Error processing customer 456 - 'phone'
# Warning: Error processing customer 457 - 'phone'
# Warning: Error processing customer 458 - 'phone'
# Warning: Error processing customer 459 - 'phone'
# Warning: Error processing customer 460 - 'phone'
# Warning: Error processing customer 461 - 'phone'
# Warning: Error processing customer 462 - 'phone'
# Warning: Error processing customer 463 - 'phone'
# Warning: Error processing customer 464 - 'phone'
# Warning: Error processing customer 465 - 'phone'
# Warning: Error processing customer 466 - 'phone'
# Warning: Error processing customer 467 - 'phone'
# Warning: Error processing customer 468 - 'phone'
# Warning: Error processing customer 469 - 'phone'
# Warning: Error processing customer 470 - 'phone'
# Warning: Error processing customer 471 - 'phone'
# Warning: Error processing customer 472 - 'phone'
# Warning: Error processing customer 473 - 'phone'
# Warning: Error processing customer 474 - 'phone'
# Warning: Error processing customer 475 - 'phone'
# Warning: Error processing customer 476 - 'phone'
# Warning: Error processing customer 477 - 'phone'
# Warning: Error processing customer 478 - 'phone'
# Warning: Error processing customer 479 - 'phone'
# Warning: Error processing customer 480 - 'phone'
# Warning: Error processing customer 481 - 'phone'
# Warning: Error processing customer 482 - 'phone'
# Warning: Error processing customer 483 - 'phone'
# Warning: Error processing customer 484 - 'phone'
# Warning: Error processing customer 485 - 'phone'
# Warning: Error processing customer 486 - 'phone'
# Warning: Error processing customer 487 - 'phone'
# Warning: Error processing customer 488 - 'phone'
# Warning: Error processing customer 489 - 'phone'
# Warning: Error processing customer 490 - 'phone'
# Warning: Error processing customer 491 - 'phone'
# Warning: Error processing customer 492 - 'phone'
# Warning: Error processing customer 493 - 'phone'
# Warning: Error processing customer 494 - 'phone'
# Warning: Error processing customer 495 - 'phone'
# Warning: Error processing customer 496 - 'phone'
# Warning: Error processing customer 497 - 'phone'
# Warning: Error processing customer 498 - 'phone'
# Warning: Error processing customer 499 - 'phone'
# Warning: Error processing customer 500 - 'phone'
# Warning: Error processing customer 501 - 'phone'
# Warning: Error processing customer 502 - 'phone'
# Warning: Error processing customer 503 - 'phone'
# Warning: Error processing customer 504 - 'phone'
# Warning: Error processing customer 505 - 'phone'
# Warning: Error processing customer 506 - 'phone'
# Warning: Error processing customer 507 - 'phone'
# Warning: Error processing customer 508 - 'phone'
# Warning: Error processing customer 509 - 'phone'
# Warning: Error processing customer 510 - 'phone'
# Warning: Error processing customer 511 - 'phone'
# Warning: Error processing customer 512 - 'phone'
# Warning: Error processing customer 513 - 'phone'
# Warning: Error processing customer 514 - 'phone'
# Warning: Error processing customer 515 - 'phone'
# Warning: Error processing customer 516 - 'phone'
# Warning: Error processing customer 517 - 'phone'
# Warning: Error processing customer 518 - 'phone'
# Warning: Error processing customer 519 - 'phone'
# Warning: Error processing customer 520 - 'phone'
# Warning: Error processing customer 521 - 'phone'
# Warning: Error processing customer 522 - 'phone'
# Warning: Error processing customer 523 - 'phone'
# Warning: Error processing customer 524 - 'phone'
# Warning: Error processing customer 525 - 'phone'
# Warning: Error processing customer 526 - 'phone'
# Warning: Error processing customer 527 - 'phone'
# Warning: Error processing customer 528 - 'phone'
# Warning: Error processing customer 529 - 'phone'
# Warning: Error processing customer 530 - 'phone'
# Warning: Error processing customer 531 - 'phone'
# Warning: Error processing customer 532 - 'phone'
# Warning: Error processing customer 533 - 'phone'
# Warning: Error processing customer 534 - 'phone'
# Warning: Error processing customer 535 - 'phone'
# Warning: Error processing customer 536 - 'phone'
# Warning: Error processing customer 537 - 'phone'
# Warning: Error processing customer 538 - 'phone'
# Warning: Error processing customer 539 - 'phone'
# Warning: Error processing customer 540 - 'phone'
# Warning: Error processing customer 541 - 'phone'
# Warning: Error processing customer 542 - 'phone'
# Warning: Error processing customer 543 - 'phone'
# Warning: Error processing customer 544 - 'phone'
# Warning: Error processing customer 545 - 'phone'
# Warning: Error processing customer 546 - 'phone'
# Warning: Error processing customer 547 - 'phone'
# Warning: Error processing customer 548 - 'phone'
# Warning: Error processing customer 549 - 'phone'
# Warning: Error processing customer 550 - 'phone'
# Warning: Error processing customer 551 - 'phone'
# Warning: Error processing customer 552 - 'phone'
# Warning: Error processing customer 553 - 'phone'
# Warning: Error processing customer 554 - 'phone'
# Warning: Error processing customer 555 - 'phone'
# Warning: Error processing customer 556 - 'phone'
# Warning: Error processing customer 557 - 'phone'
# Warning: Error processing customer 558 - 'phone'
# Warning: Error processing customer 559 - 'phone'
# Warning: Error processing customer 560 - 'phone'
# Warning: Error processing customer 561 - 'phone'
# Warning: Error processing customer 562 - 'phone'
# Warning: Error processing customer 563 - 'phone'
# Warning: Error processing customer 564 - 'phone'
# Warning: Error processing customer 565 - 'phone'
# Warning: Error processing customer 566 - 'phone'
# Warning: Error processing customer 567 - 'phone'
# Warning: Error processing customer 568 - 'phone'
# Warning: Error processing customer 569 - 'phone'
# Warning: Error processing customer 570 - 'phone'
# Warning: Error processing customer 571 - 'phone'
# Warning: Error processing customer 572 - 'phone'
# Warning: Error processing customer 573 - 'phone'
# Warning: Error processing customer 574 - 'phone'
# Warning: Error processing customer 575 - 'phone'
# Warning: Error processing customer 576 - 'phone'
# Warning: Error processing customer 577 - 'phone'
# Warning: Error processing customer 578 - 'phone'
# Warning: Error processing customer 579 - 'phone'
# Warning: Error processing customer 580 - 'phone'
# Warning: Error processing customer 581 - 'phone'
# Warning: Error processing customer 582 - 'phone'
# Warning: Error processing customer 583 - 'phone'
# Warning: Error processing customer 584 - 'phone'
# Warning: Error processing customer 585 - 'phone'
# Warning: Error processing customer 586 - 'phone'
# Warning: Error processing customer 587 - 'phone'
# Warning: Error processing customer 588 - 'phone'
# Warning: Error processing customer 589 - 'phone'
# Warning: Error processing customer 590 - 'phone'
# Warning: Error processing customer 591 - 'phone'
# Warning: Error processing customer 592 - 'phone'
# Warning: Error processing customer 593 - 'phone'
# Warning: Error processing customer 594 - 'phone'
# Warning: Error processing customer 595 - 'phone'
# Warning: Error processing customer 596 - 'phone'
# Warning: Error processing customer 597 - 'phone'
# Warning: Error processing customer 598 - 'phone'
# Warning: Error processing customer 599 - 'phone'
# Warning: Error processing customer 600 - 'phone'
# Warning: Error processing customer 601 - 'phone'
# Warning: Error processing customer 602 - 'phone'
# Warning: Error processing customer 603 - 'phone'
# Warning: Error processing customer 604 - 'phone'
# Warning: Error processing customer 605 - 'phone'
# Warning: Error processing customer 606 - 'phone'
# Warning: Error processing customer 607 - 'phone'
# Warning: Error processing customer 608 - 'phone'
# Warning: Error processing customer 609 - 'phone'
# Warning: Error processing customer 610 - 'phone'
# Warning: Error processing customer 611 - 'phone'
# Warning: Error processing customer 612 - 'phone'
# Warning: Error processing customer 613 - 'phone'
# Warning: Error processing customer 614 - 'phone'
# Warning: Error processing customer 615 - 'phone'
# Warning: Error processing customer 616 - 'phone'
# Warning: Error processing customer 617 - 'phone'
# Warning: Error processing customer 618 - 'phone'
# Warning: Error processing customer 619 - 'phone'
# Warning: Error processing customer 620 - 'phone'
# Warning: Error processing customer 621 - 'phone'
# Warning: Error processing customer 622 - 'phone'
# Warning: Error processing customer 623 - 'phone'
# Warning: Error processing customer 624 - 'phone'
# Warning: Error processing customer 625 - 'phone'
# Warning: Error processing customer 626 - 'phone'
# Warning: Error processing customer 627 - 'phone'
# Warning: Error processing customer 628 - 'phone'
# Warning: Error processing customer 629 - 'phone'
# Warning: Error processing customer 630 - 'phone'
# Warning: Error processing customer 631 - 'phone'
# Warning: Error processing customer 632 - 'phone'
# Warning: Error processing customer 633 - 'phone'
# Warning: Error processing customer 634 - 'phone'
# Warning: Error processing customer 635 - 'phone'
# Warning: Error processing customer 636 - 'phone'
# Warning: Error processing customer 637 - 'phone'
# Warning: Error processing customer 638 - 'phone'
# Warning: Error processing customer 639 - 'phone'
# Warning: Error processing customer 640 - 'phone'
# Warning: Error processing customer 641 - 'phone'
# Warning: Error processing customer 642 - 'phone'
# Warning: Error processing customer 643 - 'phone'
# Warning: Error processing customer 644 - 'phone'
# Warning: Error processing customer 645 - 'phone'
# Warning: Error processing customer 646 - 'phone'
# Warning: Error processing customer 647 - 'phone'
# Warning: Error processing customer 648 - 'phone'
# Warning: Error processing customer 649 - 'phone'
# Warning: Error processing customer 650 - 'phone'
# Warning: Error processing customer 651 - 'phone'
# Warning: Error processing customer 652 - 'phone'
# Warning: Error processing customer 653 - 'phone'
# Warning: Error processing customer 654 - 'phone'
# Warning: Error processing customer 655 - 'phone'
# Warning: Error processing customer 656 - 'phone'
# Warning: Error processing customer 657 - 'phone'
# Warning: Error processing customer 658 - 'phone'
# Warning: Error processing customer 659 - 'phone'
# Warning: Error processing customer 660 - 'phone'
# Warning: Error processing customer 661 - 'phone'
# Warning: Error processing customer 662 - 'phone'
# Warning: Error processing customer 663 - 'phone'
# Warning: Error processing customer 664 - 'phone'
# Warning: Error processing customer 665 - 'phone'
# Warning: Error processing customer 666 - 'phone'
# Warning: Error processing customer 667 - 'phone'
# Warning: Error processing customer 668 - 'phone'
# Warning: Error processing customer 669 - 'phone'
# Warning: Error processing customer 670 - 'phone'
# Warning: Error processing customer 671 - 'phone'
# Warning: Error processing customer 672 - 'phone'
# Warning: Error processing customer 673 - 'phone'
# Warning: Error processing customer 674 - 'phone'
# Warning: Error processing customer 675 - 'phone'
# Warning: Error processing customer 676 - 'phone'
# Warning: Error processing customer 677 - 'phone'
# Warning: Error processing customer 678 - 'phone'
# Warning: Error processing customer 679 - 'phone'
# Warning: Error processing customer 680 - 'phone'
# Warning: Error processing customer 681 - 'phone'
# Warning: Error processing customer 682 - 'phone'
# Warning: Error processing customer 683 - 'phone'
# Warning: Error processing customer 684 - 'phone'
# Warning: Error processing customer 685 - 'phone'
# Warning: Error processing customer 686 - 'phone'
# Warning: Error processing customer 687 - 'phone'
# Warning: Error processing customer 688 - 'phone'
# Warning: Error processing customer 689 - 'phone'
# Warning: Error processing customer 690 - 'phone'
# Warning: Error processing customer 691 - 'phone'
# Warning: Error processing customer 692 - 'phone'
# Warning: Error processing customer 693 - 'phone'
# Warning: Error processing customer 694 - 'phone'
# Warning: Error processing customer 695 - 'phone'
# Warning: Error processing customer 696 - 'phone'
# Warning: Error processing customer 697 - 'phone'
# Warning: Error processing customer 698 - 'phone'
# Warning: Error processing customer 699 - 'phone'
# Warning: Error processing customer 700 - 'phone'
# Warning: Error processing customer 701 - 'phone'
# Warning: Error processing customer 702 - 'phone'
# Warning: Error processing customer 703 - 'phone'
# Warning: Error processing customer 704 - 'phone'
# Warning: Error processing customer 705 - 'phone'
# Warning: Error processing customer 706 - 'phone'
# Warning: Error processing customer 707 - 'phone'
# Warning: Error processing customer 708 - 'phone'
# Warning: Error processing customer 709 - 'phone'
# Warning: Error processing customer 710 - 'phone'
# Warning: Error processing customer 711 - 'phone'
# Warning: Error processing customer 712 - 'phone'
# Warning: Error processing customer 713 - 'phone'
# Warning: Error processing customer 714 - 'phone'
# Warning: Error processing customer 715 - 'phone'
# Warning: Error processing customer 716 - 'phone'
# Warning: Error processing customer 717 - 'phone'
# Warning: Error processing customer 718 - 'phone'
# Warning: Error processing customer 719 - 'phone'
# Warning: Error processing customer 720 - 'phone'
# Warning: Error processing customer 721 - 'phone'
# Warning: Error processing customer 722 - 'phone'
# Warning: Error processing customer 723 - 'phone'
# Warning: Error processing customer 724 - 'phone'
# Warning: Error processing customer 725 - 'phone'
# Warning: Error processing customer 726 - 'phone'
# Warning: Error processing customer 727 - 'phone'
# Warning: Error processing customer 728 - 'phone'
# Warning: Error processing customer 729 - 'phone'
# Warning: Error processing customer 730 - 'phone'
# Warning: Error processing customer 731 - 'phone'
# Warning: Error processing customer 732 - 'phone'
# Warning: Error processing customer 733 - 'phone'
# Warning: Error processing customer 734 - 'phone'
# Warning: Error processing customer 735 - 'phone'
# Warning: Error processing customer 736 - 'phone'
# Warning: Error processing customer 737 - 'phone'
# Warning: Error processing customer 738 - 'phone'
# Warning: Error processing customer 739 - 'phone'
# Warning: Error processing customer 740 - 'phone'
# Warning: Error processing customer 741 - 'phone'
# Warning: Error processing customer 742 - 'phone'
# Warning: Error processing customer 743 - 'phone'
# Warning: Error processing customer 744 - 'phone'
# Warning: Error processing customer 745 - 'phone'
# Warning: Error processing customer 746 - 'phone'
# Warning: Error processing customer 747 - 'phone'
# Warning: Error processing customer 748 - 'phone'
# Warning: Error processing customer 749 - 'phone'
# Warning: Error processing customer 750 - 'phone'
# Warning: Error processing customer 751 - 'phone'
# Warning: Error processing customer 752 - 'phone'
# Warning: Error processing customer 753 - 'phone'
# Warning: Error processing customer 754 - 'phone'
# Warning: Error processing customer 755 - 'phone'
# Warning: Error processing customer 756 - 'phone'
# Warning: Error processing customer 757 - 'phone'
# Warning: Error processing customer 758 - 'phone'
# Warning: Error processing customer 759 - 'phone'
# Warning: Error processing customer 760 - 'phone'
# Warning: Error processing customer 761 - 'phone'
# Warning: Error processing customer 762 - 'phone'
# Warning: Error processing customer 763 - 'phone'
# Warning: Error processing customer 764 - 'phone'
# Warning: Error processing customer 765 - 'phone'
# Warning: Error processing customer 766 - 'phone'
# Warning: Error processing customer 767 - 'phone'
# Warning: Error processing customer 768 - 'phone'
# Warning: Error processing customer 769 - 'phone'
# Warning: Error processing customer 770 - 'phone'
# Warning: Error processing customer 771 - 'phone'
# Warning: Error processing customer 772 - 'phone'
# Warning: Error processing customer 773 - 'phone'
# Warning: Error processing customer 774 - 'phone'
# Warning: Error processing customer 775 - 'phone'
# Warning: Error processing customer 776 - 'phone'
# Warning: Error processing customer 777 - 'phone'
# Warning: Error processing customer 778 - 'phone'
# Warning: Error processing customer 779 - 'phone'
# Warning: Error processing customer 780 - 'phone'
# Warning: Error processing customer 781 - 'phone'
# Warning: Error processing customer 782 - 'phone'
# Warning: Error processing customer 783 - 'phone'
# Warning: Error processing customer 784 - 'phone'
# Warning: Error processing customer 785 - 'phone'
# Warning: Error processing customer 786 - 'phone'
# Warning: Error processing customer 787 - 'phone'
# Warning: Error processing customer 788 - 'phone'
# Warning: Error processing customer 789 - 'phone'
# Warning: Error processing customer 790 - 'phone'
# Warning: Error processing customer 791 - 'phone'
# Warning: Error processing customer 792 - 'phone'
# Warning: Error processing customer 793 - 'phone'
# Warning: Error processing customer 794 - 'phone'
# Warning: Error processing customer 795 - 'phone'
# Warning: Error processing customer 796 - 'phone'
# Warning: Error processing customer 797 - 'phone'
# Warning: Error processing customer 798 - 'phone'
# Warning: Error processing customer 799 - 'phone'
# Warning: Error processing customer 800 - 'phone'
# Warning: Error processing customer 801 - 'phone'
# Warning: Error processing customer 802 - 'phone'
# Warning: Error processing customer 803 - 'phone'
# Warning: Error processing customer 804 - 'phone'
# Warning: Error processing customer 805 - 'phone'
# Warning: Error processing customer 806 - 'phone'
# Warning: Error processing customer 807 - 'phone'
# Warning: Error processing customer 808 - 'phone'
# Warning: Error processing customer 809 - 'phone'
# Warning: Error processing customer 810 - 'phone'
# Warning: Error processing customer 811 - 'phone'
# Warning: Error processing customer 812 - 'phone'
# Warning: Error processing customer 813 - 'phone'
# Warning: Error processing customer 814 - 'phone'
# Warning: Error processing customer 815 - 'phone'
# Warning: Error processing customer 816 - 'phone'
# Warning: Error processing customer 817 - 'phone'
# Warning: Error processing customer 818 - 'phone'
# Warning: Error processing customer 819 - 'phone'
# Warning: Error processing customer 820 - 'phone'
# Warning: Error processing customer 821 - 'phone'
# Warning: Error processing customer 822 - 'phone'
# Warning: Error processing customer 823 - 'phone'
# Warning: Error processing customer 824 - 'phone'
# Warning: Error processing customer 825 - 'phone'
# Warning: Error processing customer 826 - 'phone'
# Warning: Error processing customer 827 - 'phone'
# Warning: Error processing customer 828 - 'phone'
# Warning: Error processing customer 829 - 'phone'
# Warning: Error processing customer 830 - 'phone'
# Warning: Error processing customer 831 - 'phone'
# Warning: Error processing customer 832 - 'phone'
# Warning: Error processing customer 833 - 'phone'
# Warning: Error processing customer 834 - 'phone'
# Warning: Error processing customer 835 - 'phone'
# Warning: Error processing customer 836 - 'phone'
# Warning: Error processing customer 837 - 'phone'
# Warning: Error processing customer 838 - 'phone'
# Warning: Error processing customer 839 - 'phone'
# Warning: Error processing customer 840 - 'phone'
# Warning: Error processing customer 841 - 'phone'
# Warning: Error processing customer 842 - 'phone'
# Warning: Error processing customer 843 - 'phone'
# Warning: Error processing customer 844 - 'phone'
# Warning: Error processing customer 845 - 'phone'
# Warning: Error processing customer 846 - 'phone'
# Warning: Error processing customer 847 - 'phone'
# Warning: Error processing customer 848 - 'phone'
# Warning: Error processing customer 849 - 'phone'
# Warning: Error processing customer 850 - 'phone'
# Warning: Error processing customer 851 - 'phone'
# Warning: Error processing customer 852 - 'phone'
# Warning: Error processing customer 853 - 'phone'
# Warning: Error processing customer 854 - 'phone'
# Warning: Error processing customer 855 - 'phone'
# Warning: Error processing customer 856 - 'phone'
# Warning: Error processing customer 857 - 'phone'
# Warning: Error processing customer 858 - 'phone'
# Warning: Error processing customer 859 - 'phone'
# Warning: Error processing customer 860 - 'phone'
# Warning: Error processing customer 861 - 'phone'
# Warning: Error processing customer 862 - 'phone'
# Warning: Error processing customer 863 - 'phone'
# Warning: Error processing customer 864 - 'phone'
# Warning: Error processing customer 865 - 'phone'
# Warning: Error processing customer 866 - 'phone'
# Warning: Error processing customer 867 - 'phone'
# Warning: Error processing customer 868 - 'phone'
# Warning: Error processing customer 869 - 'phone'
# Warning: Error processing customer 870 - 'phone'
# Warning: Error processing customer 871 - 'phone'
# Warning: Error processing customer 872 - 'phone'
# Warning: Error processing customer 873 - 'phone'
# Warning: Error processing customer 874 - 'phone'
# Warning: Error processing customer 875 - 'phone'
# Warning: Error processing customer 876 - 'phone'
# Warning: Error processing customer 877 - 'phone'
# Warning: Error processing customer 878 - 'phone'
# Warning: Error processing customer 879 - 'phone'
# Warning: Error processing customer 880 - 'phone'
# Warning: Error processing customer 881 - 'phone'
# Warning: Error processing customer 882 - 'phone'
# Warning: Error processing customer 883 - 'phone'
# Warning: Error processing customer 884 - 'phone'
# Warning: Error processing customer 885 - 'phone'
# Warning: Error processing customer 886 - 'phone'
# Warning: Error processing customer 887 - 'phone'
# Warning: Error processing customer 888 - 'phone'
# Warning: Error processing customer 889 - 'phone'
# Warning: Error processing customer 890 - 'phone'
# Warning: Error processing customer 891 - 'phone'
# Warning: Error processing customer 892 - 'phone'
# Warning: Error processing customer 893 - 'phone'
# Warning: Error processing customer 894 - 'phone'
# Warning: Error processing customer 895 - 'phone'
# Warning: Error processing customer 896 - 'phone'
# Warning: Error processing customer 897 - 'phone'
# Warning: Error processing customer 898 - 'phone'
# Warning: Error processing customer 899 - 'phone'
# Warning: Error processing customer 900 - 'phone'
# Warning: Error processing customer 901 - 'phone'
# Warning: Error processing customer 902 - 'phone'
# Warning: Error processing customer 903 - 'phone'
# Warning: Error processing customer 904 - 'phone'
# Warning: Error processing customer 905 - 'phone'
# Warning: Error processing customer 906 - 'phone'
# Warning: Error processing customer 907 - 'phone'
# Warning: Error processing customer 908 - 'phone'
# Warning: Error processing customer 909 - 'phone'
# Warning: Error processing customer 910 - 'phone'
# Warning: Error processing customer 911 - 'phone'
# Warning: Error processing customer 912 - 'phone'
# Warning: Error processing customer 913 - 'phone'
# Warning: Error processing customer 914 - 'phone'
# Warning: Error processing customer 915 - 'phone'
# Warning: Error processing customer 916 - 'phone'
# Warning: Error processing customer 917 - 'phone'
# Warning: Error processing customer 918 - 'phone'
# Warning: Error processing customer 919 - 'phone'
# Warning: Error processing customer 920 - 'phone'
# Warning: Error processing customer 921 - 'phone'
# Warning: Error processing customer 922 - 'phone'
# Warning: Error processing customer 923 - 'phone'
# Warning: Error processing customer 924 - 'phone'
# Warning: Error processing customer 925 - 'phone'
# Warning: Error processing customer 926 - 'phone'
# Warning: Error processing customer 927 - 'phone'
# Warning: Error processing customer 928 - 'phone'
# Warning: Error processing customer 929 - 'phone'
# Warning: Error processing customer 930 - 'phone'
# Warning: Error processing customer 931 - 'phone'
# Warning: Error processing customer 932 - 'phone'
# Warning: Error processing customer 933 - 'phone'
# Warning: Error processing customer 934 - 'phone'
# Warning: Error processing customer 935 - 'phone'
# Warning: Error processing customer 936 - 'phone'
# Warning: Error processing customer 937 - 'phone'
# Warning: Error processing customer 938 - 'phone'
# Warning: Error processing customer 939 - 'phone'
# Warning: Error processing customer 940 - 'phone'
# Warning: Error processing customer 941 - 'phone'
# Warning: Error processing customer 942 - 'phone'
# Warning: Error processing customer 943 - 'phone'
# Warning: Error processing customer 944 - 'phone'
# Warning: Error processing customer 945 - 'phone'
# Warning: Error processing customer 946 - 'phone'
# Warning: Error processing customer 947 - 'phone'
# Warning: Error processing customer 948 - 'phone'
# Warning: Error processing customer 949 - 'phone'
# Warning: Error processing customer 950 - 'phone'
# Warning: Error processing customer 951 - 'phone'
# Warning: Error processing customer 952 - 'phone'
# Warning: Error processing customer 953 - 'phone'
# Warning: Error processing customer 954 - 'phone'
# Warning: Error processing customer 955 - 'phone'
# Warning: Error processing customer 956 - 'phone'
# Warning: Error processing customer 957 - 'phone'
# Warning: Error processing customer 958 - 'phone'
# Warning: Error processing customer 959 - 'phone'
# Warning: Error processing customer 960 - 'phone'
# Warning: Error processing customer 961 - 'phone'
# Warning: Error processing customer 962 - 'phone'
# Warning: Error processing customer 963 - 'phone'
# Warning: Error processing customer 964 - 'phone'
# Warning: Error processing customer 965 - 'phone'
# Warning: Error processing customer 966 - 'phone'
# Warning: Error processing customer 967 - 'phone'
# Warning: Error processing customer 968 - 'phone'
# Warning: Error processing customer 969 - 'phone'
# Warning: Error processing customer 970 - 'phone'
# Warning: Error processing customer 971 - 'phone'
# Warning: Error processing customer 972 - 'phone'
# Warning: Error processing customer 973 - 'phone'
# Warning: Error processing customer 974 - 'phone'
# Warning: Error processing customer 975 - 'phone'
# Warning: Error processing customer 976 - 'phone'
# Warning: Error processing customer 977 - 'phone'
# Warning: Error processing customer 978 - 'phone'
# Warning: Error processing customer 979 - 'phone'
# Warning: Error processing customer 980 - 'phone'
# ...
# Warning: Error processing customer 22466 - 'phone'
# Warning: Error processing customer 22467 - 'phone'
# Warning: Error processing customer 22468 - 'phone'
# Warning: Error processing customer 22469 - 'phone'
# Warning: Error processing customer 22471 - 'phone'
# Warning: Error processing customer 22472 - 'phone'
# Warning: Error processing customer 22474 - 'phone'
# Warning: Error processing customer 22475 - 'phone'
# Warning: Error processing customer 22478 - 'phone'
# Warning: Error processing customer 22481 - 'phone'
# Warning: Error processing customer 22482 - 'phone'
# Warning: Error processing customer 22483 - 'phone'
# Warning: Error processing customer 22484 - 'phone'
# Warning: Error processing customer 22486 - 'phone'
# Warning: Error processing customer 22490 - 'phone'
# Warning: Error processing customer 22492 - 'phone'
# Warning: Error processing customer 22496 - 'phone'
# Warning: Error processing customer 22497 - 'phone'
# Warning: Error processing customer 22502 - 'phone'
# Warning: Error processing customer 22503 - 'phone'
# Warning: Error processing customer 22506 - 'phone'
# Warning: Error processing customer 22509 - 'phone'
# Warning: Error processing customer 22510 - 'phone'
# Warning: Error processing customer 22513 - 'phone'
# Warning: Error processing customer 22520 - 'phone'
# Warning: Error processing customer 22526 - 'phone'
# Warning: Error processing customer 22530 - 'phone'
# Warning: Error processing customer 22534 - 'phone'
# Warning: Error processing customer 22535 - 'phone'
# Warning: Error processing customer 22544 - 'phone'
# Warning: Error processing customer 22545 - 'phone'
# Warning: Error processing customer 22547 - 'phone'
# Warning: Error processing customer 22548 - 'phone'
# Warning: Error processing customer 22552 - 'phone'
# Warning: Error processing customer 22553 - 'phone'
# Warning: Error processing customer 22555 - 'phone'
# Warning: Error processing customer 22556 - 'phone'
# Warning: Error processing customer 22560 - 'phone'
# Warning: Error processing customer 22564 - 'phone'
# Warning: Error processing customer 22565 - 'phone'
# Warning: Error processing customer 22569 - 'phone'
# Warning: Error processing customer 22579 - 'phone'
# Warning: Error processing customer 22580 - 'phone'
# Warning: Error processing customer 22584 - 'phone'
# Warning: Error processing customer 22587 - 'phone'
# Warning: Error processing customer 22588 - 'phone'
# Warning: Error processing customer 22590 - 'phone'
# Warning: Error processing customer 22592 - 'phone'
# Warning: Error processing customer 22593 - 'phone'
# Warning: Error processing customer 22596 - 'phone'
# Warning: Error processing customer 22597 - 'phone'
# Warning: Error processing customer 22600 - 'phone'
# Warning: Error processing customer 22602 - 'phone'
# Warning: Error processing customer 22603 - 'phone'
# Warning: Error processing customer 22612 - 'phone'
# Warning: Error processing customer 22613 - 'phone'
# Warning: Error processing customer 22621 - 'phone'
# Warning: Error processing customer 22622 - 'phone'
# Warning: Error processing customer 22623 - 'phone'
# Warning: Error processing customer 22625 - 'phone'
# Warning: Error processing customer 22627 - 'phone'
# Warning: Error processing customer 22630 - 'phone'
# Warning: Error processing customer 22634 - 'phone'
# Warning: Error processing customer 22636 - 'phone'
# Warning: Error processing customer 22637 - 'phone'
# Warning: Error processing customer 22638 - 'phone'
# Warning: Error processing customer 22640 - 'phone'
# Warning: Error processing customer 22642 - 'phone'
# Warning: Error processing customer 22643 - 'phone'
# Warning: Error processing customer 22650 - 'phone'
# Warning: Error processing customer 22652 - 'phone'
# Warning: Error processing customer 22654 - 'phone'
# Warning: Error processing customer 22657 - 'phone'
# Warning: Error processing customer 22661 - 'phone'
# Warning: Error processing customer 22664 - 'phone'
# Warning: Error processing customer 22667 - 'phone'
# Warning: Error processing customer 22672 - 'phone'
# Warning: Error processing customer 22677 - 'phone'
# Warning: Error processing customer 22680 - 'phone'
# Warning: Error processing customer 22684 - 'phone'
# Warning: Error processing customer 22685 - 'phone'
# Warning: Error processing customer 22697 - 'phone'
# Warning: Error processing customer 22704 - 'phone'
# Warning: Error processing customer 22705 - 'phone'
# Warning: Error processing customer 22708 - 'phone'
# Warning: Error processing customer 22712 - 'phone'
# Warning: Error processing customer 22713 - 'phone'
# Warning: Error processing customer 22714 - 'phone'
# Warning: Error processing customer 22717 - 'phone'
# Warning: Error processing customer 22720 - 'phone'
# Warning: Error processing customer 22722 - 'phone'
# Warning: Error processing customer 22723 - 'phone'
# Warning: Error processing customer 22725 - 'phone'
# Warning: Error processing customer 22726 - 'phone'
# Warning: Error processing customer 22735 - 'phone'
# Warning: Error processing customer 22739 - 'phone'
# Warning: Error processing customer 22740 - 'phone'
# Warning: Error processing customer 22747 - 'phone'
# Warning: Error processing customer 22753 - 'phone'
# Warning: Error processing customer 22754 - 'phone'
# Warning: Error processing customer 22756 - 'phone'
# Warning: Error processing customer 22758 - 'phone'
# Warning: Error processing customer 22760 - 'phone'
# Warning: Error processing customer 22763 - 'phone'
# Warning: Error processing customer 22764 - 'phone'
# Warning: Error processing customer 22765 - 'phone'
# Warning: Error processing customer 22767 - 'phone'
# Warning: Error processing customer 22768 - 'phone'
# Warning: Error processing customer 22770 - 'phone'
# Warning: Error processing customer 22771 - 'phone'
# Warning: Error processing customer 22773 - 'phone'
# Warning: Error processing customer 22774 - 'phone'
# Warning: Error processing customer 22780 - 'phone'
# Warning: Error processing customer 22783 - 'phone'
# Warning: Error processing customer 22784 - 'phone'
# Warning: Error processing customer 22786 - 'phone'
# Warning: Error processing customer 22789 - 'phone'
# Warning: Error processing customer 22790 - 'phone'
# Warning: Error processing customer 22794 - 'phone'
# Warning: Error processing customer 22799 - 'phone'
# Warning: Error processing customer 22802 - 'phone'
# Warning: Error processing customer 22804 - 'phone'
# Warning: Error processing customer 22805 - 'phone'
# Warning: Error processing customer 22809 - 'phone'
# Warning: Error processing customer 22811 - 'phone'
# Warning: Error processing customer 22813 - 'phone'
# Warning: Error processing customer 22816 - 'phone'
# Warning: Error processing customer 22821 - 'phone'
# Warning: Error processing customer 22823 - 'phone'
# Warning: Error processing customer 22824 - 'phone'
# Warning: Error processing customer 22826 - 'phone'
# Warning: Error processing customer 22834 - 'phone'
# Warning: Error processing customer 22837 - 'phone'
# Warning: Error processing customer 22839 - 'phone'
# Warning: Error processing customer 22840 - 'phone'
# Warning: Error processing customer 22844 - 'phone'
# Warning: Error processing customer 22847 - 'phone'
# Warning: Error processing customer 22850 - 'phone'
# Warning: Error processing customer 22851 - 'phone'
# Warning: Error processing customer 22853 - 'phone'
# Warning: Error processing customer 22854 - 'phone'
# Warning: Error processing customer 22861 - 'phone'
# Warning: Error processing customer 22866 - 'phone'
# Warning: Error processing customer 22868 - 'phone'
# Warning: Error processing customer 22870 - 'phone'
# Warning: Error processing customer 22872 - 'phone'
# Warning: Error processing customer 22873 - 'phone'
# Warning: Error processing customer 22874 - 'phone'
# Warning: Error processing customer 22878 - 'phone'
# Warning: Error processing customer 22882 - 'phone'
# Warning: Error processing customer 22887 - 'phone'
# Warning: Error processing customer 22890 - 'phone'
# Warning: Error processing customer 22894 - 'phone'
# Warning: Error processing customer 22908 - 'phone'
# Warning: Error processing customer 22911 - 'phone'
# Warning: Error processing customer 22915 - 'phone'
# Warning: Error processing customer 22916 - 'phone'
# Warning: Error processing customer 22917 - 'phone'
# Warning: Error processing customer 22927 - 'phone'
# Warning: Error processing customer 22932 - 'phone'
# Warning: Error processing customer 22935 - 'phone'
# Warning: Error processing customer 22939 - 'phone'
# Warning: Error processing customer 22940 - 'phone'
# Warning: Error processing customer 22941 - 'phone'
# Warning: Error processing customer 22946 - 'phone'
# Warning: Error processing customer 22947 - 'phone'
# Warning: Error processing customer 22948 - 'phone'
# Warning: Error processing customer 22951 - 'phone'
# Warning: Error processing customer 22956 - 'phone'
# Warning: Error processing customer 22957 - 'phone'
# Warning: Error processing customer 22960 - 'phone'
# Warning: Error processing customer 22961 - 'phone'
# Warning: Error processing customer 22965 - 'phone'
# Warning: Error processing customer 22968 - 'phone'
# Warning: Error processing customer 22970 - 'phone'
# Warning: Error processing customer 22972 - 'phone'
# Warning: Error processing customer 22974 - 'phone'
# Warning: Error processing customer 22977 - 'phone'
# Warning: Error processing customer 22982 - 'phone'
# Warning: Error processing customer 22985 - 'phone'
# Warning: Error processing customer 22988 - 'phone'
# Warning: Error processing customer 22994 - 'phone'
# Warning: Error processing customer 22996 - 'phone'
# Warning: Error processing customer 23003 - 'phone'
# Warning: Error processing customer 23006 - 'phone'
# Warning: Error processing customer 23007 - 'phone'
# Warning: Error processing customer 23008 - 'phone'
# Warning: Error processing customer 23009 - 'phone'
# Warning: Error processing customer 23022 - 'phone'
# Warning: Error processing customer 23023 - 'phone'
# Warning: Error processing customer 23026 - 'phone'
# Warning: Error processing customer 23030 - 'phone'
# Warning: Error processing customer 23031 - 'phone'
# Warning: Error processing customer 23032 - 'phone'
# Warning: Error processing customer 23034 - 'phone'
# Warning: Error processing customer 23035 - 'phone'
# Warning: Error processing customer 23036 - 'phone'
# Warning: Error processing customer 23040 - 'phone'
# Warning: Error processing customer 23041 - 'phone'
# Warning: Error processing customer 23046 - 'phone'
# Warning: Error processing customer 23051 - 'phone'
# Warning: Error processing customer 23056 - 'phone'
# Warning: Error processing customer 23067 - 'phone'
# Warning: Error processing customer 23069 - 'phone'
# Warning: Error processing customer 23070 - 'phone'
# Warning: Error processing customer 23071 - 'phone'
# Warning: Error processing customer 23072 - 'phone'
# Warning: Error processing customer 23075 - 'phone'
# Warning: Error processing customer 23076 - 'phone'
# Warning: Error processing customer 23078 - 'phone'
# Warning: Error processing customer 23079 - 'phone'
# Warning: Error processing customer 23096 - 'phone'
# Warning: Error processing customer 23105 - 'phone'
# Warning: Error processing customer 23107 - 'phone'
# Warning: Error processing customer 23108 - 'phone'
# Warning: Error processing customer 23110 - 'phone'
# Warning: Error processing customer 23111 - 'phone'
# Warning: Error processing customer 23113 - 'phone'
# Warning: Error processing customer 23114 - 'phone'
# Warning: Error processing customer 23119 - 'phone'
# Warning: Error processing customer 23121 - 'phone'
# Warning: Error processing customer 23124 - 'phone'
# Warning: Error processing customer 23126 - 'phone'
# Warning: Error processing customer 23128 - 'phone'
# Warning: Error processing customer 23130 - 'phone'
# Warning: Error processing customer 23134 - 'phone'
# Warning: Error processing customer 23135 - 'phone'
# Warning: Error processing customer 23142 - 'phone'
# Warning: Error processing customer 23148 - 'phone'
# Warning: Error processing customer 23152 - 'phone'
# Warning: Error processing customer 23153 - 'phone'
# Warning: Error processing customer 23155 - 'phone'
# Warning: Error processing customer 23156 - 'phone'
# Warning: Error processing customer 23167 - 'phone'
# Warning: Error processing customer 23169 - 'phone'
# Warning: Error processing customer 23170 - 'phone'
# Warning: Error processing customer 23172 - 'phone'
# Warning: Error processing customer 23177 - 'phone'
# Warning: Error processing customer 23178 - 'phone'
# Warning: Error processing customer 23182 - 'phone'
# Warning: Error processing customer 23185 - 'phone'
# Warning: Error processing customer 23186 - 'phone'
# Warning: Error processing customer 23188 - 'phone'
# Warning: Error processing customer 23192 - 'phone'
# Warning: Error processing customer 23193 - 'phone'
# Warning: Error processing customer 23199 - 'phone'
# Warning: Error processing customer 23202 - 'phone'
# Warning: Error processing customer 23205 - 'phone'
# Warning: Error processing customer 23206 - 'phone'
# Warning: Error processing customer 23207 - 'phone'
# Warning: Error processing customer 23210 - 'phone'
# Warning: Error processing customer 23215 - 'phone'
# Warning: Error processing customer 23218 - 'phone'
# Warning: Error processing customer 23219 - 'phone'
# Warning: Error processing customer 23222 - 'phone'
# Warning: Error processing customer 23224 - 'phone'
# Warning: Error processing customer 23225 - 'phone'
# Warning: Error processing customer 23228 - 'phone'
# Warning: Error processing customer 23233 - 'phone'
# Warning: Error processing customer 23237 - 'phone'
# Warning: Error processing customer 23238 - 'phone'
# Warning: Error processing customer 23239 - 'phone'
# Warning: Error processing customer 23242 - 'phone'
# Warning: Error processing customer 23245 - 'phone'
# Warning: Error processing customer 23251 - 'phone'
# Warning: Error processing customer 23252 - 'phone'
# Warning: Error processing customer 23254 - 'phone'
# Warning: Error processing customer 23255 - 'phone'
# Warning: Error processing customer 23256 - 'phone'
# Warning: Error processing customer 23260 - 'phone'
# Warning: Error processing customer 23263 - 'phone'
# Warning: Error processing customer 23272 - 'phone'
# Warning: Error processing customer 23277 - 'phone'
# Warning: Error processing customer 23279 - 'phone'
# Warning: Error processing customer 23282 - 'phone'
# Warning: Error processing customer 23287 - 'phone'
# Warning: Error processing customer 23288 - 'phone'
# Warning: Error processing customer 23289 - 'phone'
# Warning: Error processing customer 23292 - 'phone'
# Warning: Error processing customer 23294 - 'phone'
# Warning: Error processing customer 23295 - 'phone'
# Warning: Error processing customer 23299 - 'phone'
# Warning: Error processing customer 23300 - 'phone'
# Warning: Error processing customer 23309 - 'phone'
# Warning: Error processing customer 23310 - 'phone'
# Warning: Error processing customer 23319 - 'phone'
# Warning: Error processing customer 23321 - 'phone'
# Warning: Error processing customer 23325 - 'phone'
# Warning: Error processing customer 23327 - 'phone'
# Warning: Error processing customer 23328 - 'phone'
# Warning: Error processing customer 23330 - 'phone'
#
# Plan Distribution Analysis:
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 175
#     173 print("\nPlan Distribution Analysis:")
#     174 print("-" * 50)
# --> 175 plan_dist = recs_df["plan_name"].value_counts()
#     176 print("\nRecommendations per plan:")
#     177 print(plan_dist)
#
# File c:\CTS Hackathon\Price_Plan_Recommendation-main\.venv\lib\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File c:\CTS Hackathon\Price_Plan_Recommendation-main\.venv\lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'plan_name'

# %%
import joblib, json
from pathlib import Path
OUT_DIR_M = Path(r"C:\Users\look4\Price_Plan_Recommendation\models")
OUT_DIR = Path(r"C:\Users\look4\Price_Plan_Recommendation\data\processed")
OUT_DIR.mkdir(parents=True, exist_ok=True)

# --- Save datasets ---
df.to_csv(OUT_DIR / "customers_with_clusters.csv", index=False)
recs_df.to_csv(OUT_DIR / "top3_recommendations_ph.csv", index=False)
catalog_df.to_csv(OUT_DIR / "plan_catalog.csv", index=False)

print("✅ Datasets saved:")
print(" - customers_with_clusters.csv")
print(" - top3_recommendations.csv")
print(" - plan_catalog.csv")

# --- Save model pipeline ---
model_bundle = {
    "features": features,
    "share_cols": share_cols,
    "scaler": scaler,
    "pca": pca,
    "kmeans": kmeans,
}

MODEL_PATH = OUT_DIR_M / "model.pkl"
joblib.dump(model_bundle, MODEL_PATH)

with open(OUT_DIR / "model_features.json", "w") as f:
    json.dump({"features": features, "share_cols": share_cols}, f, indent=2)

print("✅ Model saved:")
print(" -", MODEL_PATH)
print(" - model_features.json")
# Out:
# ✅ Datasets saved:
#  - customers_with_clusters.csv
#  - top3_recommendations.csv
#  - plan_catalog.csv
# ✅ Model saved:
#  - C:\Users\look4\Price_Plan_Recommendation\models\model.pkl
#  - model_features.json
